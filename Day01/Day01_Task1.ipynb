# %% [markdown]
# # Task 1: Environment Setup & First Script
#
# ## Future AI Engineer - Python Environment Setup
#
# **Student Name:** Areeba Amjad
# **Task:** Environment Setup & First Script
# **Date:** August 5, 2026

# %% [markdown]
# ## 1. Introduction
#
# This task focuses on setting up the Python development environment
# and creating the first Python script.
#
# The main objectives of this task are:
#
# - Install and configure Python.
# - Set up Visual Studio Code.
# - Create a Python project folder.
# - Create the `app.py` Python script.
# - Run the script using the VS Code terminal.
# - Document the setup process and troubleshooting steps.

# %% [markdown]
# ## 2. Environment Setup
#
# The development environment was prepared using Python and Visual
# Studio Code.
#
# ### Tools Used
#
# - Python
# - Visual Studio Code
# - Python extension for Visual Studio Code
# - Pylance extension
# - Python Debugger extension
#
# These tools were configured to write, run, and debug Python programs.

# %% [markdown]
# ## 3. Installation Steps
#
# ### Step 1: Install Python
#
# Python was installed to provide the environment required to
# execute Python programs.
#
# ### Step 2: Install Visual Studio Code
#
# Visual Studio Code was installed as the code editor for Python
# development.
#
# ### Step 3: Install Python Extensions
#
# The following extensions were installed:
#
# - Python
# - Pylance
# - Python Debugger
#
# ### Step 4: Create a Project Folder
#
# A project folder was created to organize the Python files and
# related project resources.
#
# ### Step 5: Open the Project in Visual Studio Code
#
# The project folder was opened in Visual Studio Code so that Python
# files could be created and executed.

# %% [markdown]
# ## 4. Installation Screenshots
#
# The following screenshot shows the installation process.
#
# ![installation.png](attachment:53290115-0bd2-4fc1-b7a0-3d124fde4134.png)
# ![Untitled 3.png](attachment:11b247ad-aad0-4cce-8354-5695ed654ad2.png)
# ![Untitled 6.png](attachment:594efe4c-6548-433a-80ed-2a71e4450adf.png)

# %% [markdown]
# ## 5. Python Script Code
#
# The following code was written in the `app.py` file to display a
# greeting message.

# %%
print("Hi, this is Areeba, future AI engineer!")
# Out:
# Hi, this is Areeba, future AI engineer!

# %% [markdown]
# ## 6. Script Execution in VS Code Terminal
#
# The `app.py` script was successfully executed using the VS Code
# terminal.
#
# The command used was:
#
# `python3 app.py`
#
# The output confirmed that the Python script executed successfully.
# ![Untitled :.png](attachment:d09364a2-578d-40cc-bf7c-a9a3c93d0e01.png)

# %% [markdown]
# ## 7. Troubleshooting and Debugging
#
# During the setup process, some issues related to installation and
# storage were encountered.
#
# An error also occurred while trying to run the `app.py` script in
# the VS Code terminal. The script did not execute successfully at
# first because the file had not been saved properly.
#
# After saving the `app.py` file, the error was resolved. The script
# was then executed successfully in the VS Code terminal and produced
# the expected output.
#
# This troubleshooting process helped me understand the importance of
# saving Python files before executing them.

# %% [markdown]
# ## 8. References
#
# The following sources were consulted during the setup and research:
#
# 1. OpenAI ChatGPT — Python environment setup and troubleshooting.
# 2. OpenAI ChatGPT — Visual Studio Code and Python setup.
# 3. OpenAI ChatGPT — PEP 8 coding standards and documentation.
# 4. Python Documentation — Official Python documentation.
#    https://docs.python.org/3/
#
# **Date accessed:** August 5, 2026

# %% [markdown]
# ## 9. Summary
#
# In this task, I learned how to set up a Python development
# environment, create a Python project, write a Python script, and
# execute the script using the VS Code terminal.
#
# I also learned how to document the development process in a Jupyter
# Notebook, add and upload screenshots, include execution results,
# follow PEP 8 standards, and record troubleshooting steps.
#
# During the setup, I encountered some errors while running the Python
# script and learned how to identify and resolve them. I also learned
# how to save and organize files correctly to avoid execution errors.
#
# The successful execution of `app.py` confirmed that the Python
# environment was correctly configured. Overall, this task improved my
# understanding of Python setup, Jupyter Notebook documentation,
# screenshot handling, debugging, and basic development practices.
