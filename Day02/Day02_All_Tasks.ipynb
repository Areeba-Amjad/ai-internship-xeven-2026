# %% [markdown]
# # Day 02: Python Data Types and Variables
#
# This notebook documents the practical tasks and research
# completed during Day 2 of the AI Internship.
#
# ## Tasks Covered
#
# 1. Task 1: Data Types Explorer
# 2. Task 2: Interactive Calculator
# 3. Task 3: Research – Python Memory Management and Data Types

# %% [markdown]
# # Day 02: Python Data Types and Variables
#
# This notebook documents the practical tasks and research
# completed during Day 2 of the AI Internship.
#
# ## Tasks Covered
#
# 1. Task 1: Data Types Explorer
# 2. Task 2: Interactive Calculator
# 3. Task 3: Research – Python Memory Management and Data Types

# %% [markdown]
# # Task 1: Data Types Explorer
#
# This task demonstrates basic Python data types including
# integers, floating-point numbers, Boolean values, and strings.
#
# It also demonstrates type checking using the `type()` function
# and type conversion between different data types.

# %%
# Integer variable
age = 21

# Float variable
height = 5.5

# Boolean variable
is_student = True

# String variable
name = "Areeba"

# Display values and types
print("===== Python Data Types =====")
print("Integer:", age)
print("Type:", type(age))

print("\nFloat:", height)
print("Type:", type(height))

print("\nBoolean:", is_student)
print("Type:", type(is_student))

print("\nString:", name)
print("Type:", type(name))
# Out:
# ===== Python Data Types =====
# Integer: 21
# Type: <class 'int'>
#
# Float: 5.5
# Type: <class 'float'>
#
# Boolean: True
# Type: <class 'bool'>
#
# String: Areeba
# Type: <class 'str'>

# %% [markdown]
# # Task 2: Interactive Calculator
#
# This task demonstrates an interactive calculator using
# `input()`.
#
# The program takes two numbers from the user and calculates
# their sum, difference, product, and quotient.
#
# Error handling is implemented using `try-except` to handle
# invalid inputs and division by zero.

# %%
"""
Interactive Calculator

This script asks the user for two numbers and calculates their
sum, difference, product, and quotient. It also handles invalid
inputs and division by zero.
"""

try:
    # Ask the user for the first number.
    first_number = float(input("Enter the first number: "))

    # Ask the user for the second number.
    second_number = float(input("Enter the second number: "))

    # Calculate the sum.
    sum_result = first_number + second_number

    # Calculate the difference.
    difference_result = first_number - second_number

    # Calculate the product.
    product_result = first_number * second_number

    # Calculate the quotient.
    if second_number == 0:
        quotient_result = "Cannot divide by zero"
    else:
        quotient_result = first_number / second_number

    # Display the calculator results.
    print("\n===== Calculator Results =====")
    print(
        f"The sum of {first_number:g} and {second_number:g} is: "
        f"{sum_result:g}"
    )
    print(
        f"The difference of {first_number:g} and {second_number:g} is: "
        f"{difference_result:g}"
    )
    print(
        f"The product of {first_number:g} and {second_number:g} is: "
        f"{product_result:g}"
    )
    print(
        f"The quotient of {first_number:g} and {second_number:g} is: "
        f"{quotient_result}"
    )

except ValueError:
    # Handle non-numeric input.
    print("Error: Please enter valid numbers.")
# Out:
# Enter the first number:  5
# Enter the second number:  3
# ===== Calculator Results =====
# The sum of 5 and 3 is: 8
# The difference of 5 and 3 is: 2
# The product of 5 and 3 is: 15
# The quotient of 5 and 3 is: 1.6666666666666667

# %% [markdown]
# # Task 3: Research – Python Memory Management and Data Types
#
# This research task explores Python memory management, data
# types, mutable and immutable objects, and variable naming
# best practices.
#
# Three AI sources and one technical article were researched.

# %% [markdown]
# 1. ChatGPT Research
#
# Research Question
#
# How does Python handle memory for different data types?
#
# Key Takeaways
#
# Python manages memory automatically.
# Python stores objects in memory and variables refer to those objects.
# Different data types can require different amounts of memory.
# Python uses automatic memory management.
# Garbage collection helps manage objects that are no longer needed.
# Source
#
# ChatGPT – OpenAI
#
# Date Consulted: August 6, 2026

# %% [markdown]
# 2. Gemini Research
#
# Research Question
#
# Explain mutable vs immutable types in Python with examples.
#
# Key Takeaways
#
# Mutable objects can be changed after they are created.
# Immutable objects cannot be changed after they are created.
# Lists and dictionaries are examples of mutable types.
# Integers, floats, strings, and tuples are examples of immutable types.
# Understanding mutability helps prevent unexpected changes when working with Python objects.
# Source
#
# Google Gemini
#
# Date Consulted: August 6, 2026

# %% [markdown]
# 3. Claude Research
#
# Research Question
#
# What are best practices for naming variables in Python?
#
# Key Takeaways
#
# Use descriptive and meaningful variable names.
# Use lowercase_with_underscores for variable names.
# Avoid unclear names such as x and y.
# Use names that clearly describe the purpose of a variable.
# Follow Python PEP 8 naming conventions.
# Source
#
# Claude – Anthropic
#
# Date Consulted: August 6, 2026

# %% [markdown]
# 4. Article Research
#
# Article Title
#
# Memory Management in Python
#
# Website
#
# GeeksforGeeks
#
# Key Takeaways
#
# Python manages memory automatically, so programmers do not normally need to manually allocate and deallocate memory.
# Python uses reference counting to keep track of references to objects.
# When an object is no longer referenced, its memory can be released.
# Garbage collection helps remove objects that are no longer being used.
# Python uses memory allocation mechanisms to store objects during program execution.
# Small immutable objects such as some integers and strings can be reused through internal optimization.
# Python memory can be understood through stack and heap memory, which have different roles in program execution.
# Date Accessed
#
# August 6, 2026
#
# Article Last Updated
#
# August 18, 2025
#
# URL
#
# https://www.geeksforgeeks.org/python/memory-management-in-python/

# %% [markdown]
# 5. Comparison of Research Sources
#
# Source	Main Topic	Key Learning
# ChatGPT	Memory management	Python manages memory automatically
# Gemini	Mutable vs immutable	Some objects can be changed and others cannot
# Claude	Variable naming	Descriptive names and PEP 8 improve readability
# Article	Data types and memory	Data types and objects have different memory needs

# %% [markdown]
# # References
#
# ### 1. OpenAI ChatGPT
#
# **Research Question:**
# "How does Python handle memory for different data types?"
#
# **Date Consulted:** August 6, 2026
#
# ---
#
# ### 2. Google Gemini
#
# **Research Question:**
# "Explain mutable vs immutable types in Python with examples."
#
# **Date Consulted:** August 6, 2026
#
# ---
#
# ### 3. Anthropic Claude
#
# **Research Question:**
# "What are best practices for naming variables in Python?"
#
# **Date Consulted:** August 6, 2026
#
# ---
#
# ### 4. GeeksforGeeks
#
# **Article Title:**
# "Memory Management in Python"
#
# **Website:** GeeksforGeeks
#
# **Date Accessed:** August 6, 2026
#
# **Article Last Updated:** August 18, 2025
# **URL:** https://www.geeksforgeeks.org/python/memory-management-in-python/
